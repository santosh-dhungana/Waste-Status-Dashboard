# %%
import geopandas as gpd
import pandas as pd
import glob
file = glob.glob('data/Turkey_W*.txt')
df = pd.read_csv(file[0], sep ='\t', header=0)
df.tail()
# Out:
#    Municipal waste services and management indicators, 1994-2022     2001  \
# 8   Average amount of municipal waste per capita (...                1.35
# 9   Municipal waste management (Thousand tonnes/ye...                 NaN
# 10                         Waste treatment facilities               8 522
# 11                       Municipality's dumping sites              14 570
# 12                          Other disposal methods(3)               2 042
#
#        2002     2003     2004     2006     2008     2010     2012     2014  \
# 8      1.34     1.38     1.31     1.21     1.15     1.14     1.12     1.08
# 9       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 10    7 430    7 758    7 353    9 683   11 223   13 941   15 639   17 933
# 11   16 310   16 567   16 416   14 941   12 678   11 001    9 772    9 935
# 12    1 634    1 793    1 246      656      460      334      437      141
#
#        2016     2018     2020     2022
# ...

# %%
gdf = gpd.read_file('data/provinces/turkey-admin-level-4.geojson')
#print(gdf['name:en'].sort_values().unique(), len(gdf['name:en'].sort_values().unique()))
gdf.loc[:80, ['name:en', 'geometry']].rename({'name:en':'Provinces'}, axis=1).to_file('data/provinces/provincesonly.geojson', driver='GeoJSON')

# %%
waste_file = glob.glob('TurkeyDash.xlsx')

manuf_waste = pd.read_excel(waste_file[0], sheet_name ='Sheet11', header=2).iloc[:, 1:].rename({'Unnamed: 1':'Industry Sub-sectors'}, axis=1)
manuf_waste.to_csv('./data/WasteByIndustrySubSector.csv')

# %%
spc_df = pd.read_csv('./data/SPC.txt', sep='\t')
# for i, col in enumerate(spc_df.columns):
#     if i!=0 and spc_df[col].dtypes =='object':

#         spc_df[col]= pd.to_numeric(spc_df[col].apply(lambda x : str(x).replace(' ', '')), errors='coerce')

#df["fill_value"] = pd.qcut(pd.to_numeric(df['Population'], errors='coerce').fillna(0), 5, labels=False)
# df= df.dropna(axis=0).to_csv('TurkeyWastemanagement_status.csv', index=None)
spc_df.to_csv('./data/SPC.csv')

# %%
def spc_data_format(path):
        df = pd.read_csv(path, index_col=0)
        print(df.head())
        df = df.transpose().reset_index().rename(columns={'index': 'Year'})
        df['Year'] = df['Year'].astype(int)
        for col in df.columns[1:]:
            df[col] = pd.to_numeric(df[col], errors='coerce')
        return df

spc_data = spc_data_format("data/SPC.csv")
spc_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 9
#       6             df[col] = pd.to_numeric(df[col], errors='coerce')
#       7         return df
# ----> 9 spc_data = spc_data_format("data/SPC.csv")
#      10 spc_data
#
# Cell In[41], line 4, in spc_data_format(path)
#       2 df = pd.read_csv(path, index_col=0)
#       3 df = df.transpose().reset_index().rename(columns={'index': 'Year'})
# ----> 4 df['Year'] = df['Year'].astype(int)
#       5 for col in df.columns[1:]:
#       6     df[col] = pd.to_numeric(df[col], errors='coerce')
#
# File ~/.pyenv/versions/streamlit_dashboard/lib/python3.10/site-packages/pandas/core/generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
# ...
